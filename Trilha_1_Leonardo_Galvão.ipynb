# %% [markdown]
# <a href="https://colab.research.google.com/github/LeoGsilva0518/Learing_DataScience/blob/main/Trilha_1_Leonardo_Galv%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# "A frequência de palavras e letras em corpos de texto tem sido bastante estudada para diversos propósitos, sendo um deles a criptografia."
#
# **Lei de Zipf**
# Trata-se de uma lei de potências sobre a distribuição de valores de acordo com o nº de ordem numa lista. Numa lista, o membro n teria uma relação de valor com o 1º da lista segundo 1/n. Por exemplo, numa língua a frequência com que surgem as diversas palavras segue uma distribuição que se pode aproximar por:
#
# ## Pn ~ 1/n^a
#
# onde Pn representa a frequência de uma palavra ordenada na n-ésima posição e o expoente a é próximo da unidade. Isto significa que o segundo elemento se repetirá aproximadamente com uma frequência que é metade da do primeiro, e o terceiro elemento com uma frequência de 1/3 e assim sucessivamente.
#
# O objetivo desta atividade é demonstrar a **Lei de Zipf** através de um conjunto de dados obtidos através de textos na internet.

# %%
#Acessando o wikipedia 
# !pip install wikipedia 

from IPython import display
from IPython.display import clear_output
clear_output()

# %%
# Selecionando a pagina do Wikipedia.
# Importação do pacote wikipedia
import wikipedia

# %%
# Selecionando a pagina no winkipedia.

text = wikipedia.page('Breaking Bad', auto_suggest=False).section('Critical reception')

#Tamanho do texto em quantidade de palavras.
len(text)
# Out:
# 7090

# %%
#Exibindo o texto.
text
# Out:
# 'Breaking Bad received widespread critical acclaim and has been praised by many critics as one of the greatest television shows of all time. On the review aggregator website Metacritic (using a scale of 0–100), the first season scored 73, the second 84, the third 89, the fourth 96, and the fifth 99. The American Film Institute listed Breaking Bad as one of the top ten television series of 2008, 2010, 2011, 2012 and 2013. In 2013, TV Guide ranked it as the ninth greatest TV series of all time. By its end, the series was among the most-watched cable shows on American television, with audience numbers doubling from the fourth season to the fifth. A 2015 survey by The Hollywood Reporter of 2,800 actors, producers, directors, and other industry people named Breaking Bad as their #2 favorite show. In 2016, Rolling Stone ranked it third on its list of 100 Greatest TV Shows of All Time. In September 2019, The Guardian ranked the show fifth on its list of the 100 best TV shows of the 21st century, describing it as "The show that arguably killed off the antihero drama; nothing since has been able to top the depraved descent made by Walter White (a never-better Bryan Cranston), from milquetoast chemistry teacher to meth overlord, and few have dared to try." In 2021, Empire ranked Breaking Bad at number one on their list of The 100 Greatest TV Shows of All Time. Allen St. John of Forbes called it "The best TV show ever". In 2021, it was voted the third-best TV series of the 21st century by the BBC, as picked by 206 TV experts from around the world.For the first season, the series saw a generally positive reception. New York Post critic Linda Stasi praised the series, particularly the acting of Cranston and Paul, stating "Cranston and Paul are so good, it\'s astounding. I\'d say the two have created great chemistry, but I\'m ashamed to say such a cheap thing." Robert Bianco of USA Today also praised Cranston and Paul, exclaiming "There is humor in the show, mostly in Walt\'s efforts to impose scholarly logic on the business and on his idiot apprentice, a role Paul plays very well. But even their scenes lean toward the suspenseful, as the duo learns that killing someone, even in self-defense, is ugly, messy work."The second season saw critical acclaim. Entertainment Weekly critic Ken Tucker stated "Bad is a superlatively fresh metaphor for a middle-age crisis: It took cancer and lawbreaking to jolt Walt out of his suburban stupor, to experience life again—to take chances, risk danger, do things he didn\'
ievement with no evident missteps In fact it looks as if Gilligans bold vision for Breaking Bad now duly rewarded against all odds has invigorated everyone involved in the project You can sense its maturity and rising ambition in each episode Horror novelist Stephen King lauded the series comparing it to the likes of Twin Peaks and Blue Velvet\n\nThe third season also saw critical acclaim Time proclaimed Its a drama that has chosen the slow burn over the flashy explosion and its all the hotter for that choice Newsday stated Breaking Bad was still TVs best series and it stayed true to itself Tim Goodman praised the writing acting and cinematography pointing out the visual adventurousness of the series Goodman went on to call the shows visuals a combination of staggering beauty  the directors make use of numerous wideangle landscape portraits  and transfixing weirdness After the finale aired The AV Club said that season three was one of televisions finest dramatic accomplishments And what makes it so exciting  what makes the recognition of the current golden age so pressing  is that the season has not been as another reviewer put it in another co ...

# %%
# Importando nltk corpus uma biblioteca que permite a utilização de stop words.
import nltk.corpus

# %%
#importando a função word_tokenize, esta é uma função em Python que divide uma determinada frase em palavras usando a biblioteca NLTK.
import nltk
from nltk.tokenize import word_tokenize

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Separando o texto em palavras.
List_tokens = word_tokenize(text_clean)

# %%
# Criando uma lista de palabras.
for word in enumerate(List_tokens):
  print(word)
# Out:
# (0, 'Breaking')
# (1, 'Bad')
# (2, 'received')
# (3, 'widespread')
# (4, 'critical')
# (5, 'acclaim')
# (6, 'and')
# (7, 'has')
# (8, 'been')
# (9, 'praised')
# (10, 'by')
# (11, 'many')
# (12, 'critics')
# (13, 'as')
# (14, 'one')
# (15, 'of')
# (16, 'the')
# (17, 'greatest')
# (18, 'television')
# (19, 'shows')
# (20, 'of')
# (21, 'all')
# (22, 'time')
# (23, 'On')
# (24, 'the')
# (25, 'review')
# (26, 'aggregator')
# (27, 'website')
# (28, 'Metacritic')
# (29, 'using')
# (30, 'a')
# (31, 'scale')
# (32, 'of')
# (33, '0100')
# (34, 'the')
# (35, 'first')
# (36, 'season')
# (37, 'scored')
# (38, '73')
# (39, 'the')
# (40, 'second')
# (41, '84')
# (42, 'the')
# (43, 'third')
# (44, '89')
# (45, 'the')
# (46, 'fourth')
# (47, '96')
# (48, 'and')
# (49, 'the')
# (50, 'fifth')
# (51, '99')
# (52, 'The')
# (53, 'American')
# (54, 'Film')
# (55, 'Institute')
# (56, 'listed')
# (57, 'Breaking')
# (58, 'Bad')
# (59, 'as')
# (60, 'one')
# (61, 'of')
# (62, 'the')
# (63, 'top')
# (64, 'ten')
# (65, 'television')
# (66, 'series')
# (67, 'of')
# (68, '2008')
# (69, '2010')
# (70, '2011')
# (71, '2012')
# (72, 'and')
# (73, '2013')
# (74, 'In')
# (75, '2013')
# (76, 'TV')
# (77, 'Guide')
# (78, 'ranked')
# (79, 'it')
# (80, 'as')
# (81, 'the')
# (82, 'ninth')
# (83, 'greatest')
# (84, 'TV')
# (85, 'series')
# (86, 'of')
# (87, 'all')
# (88, 'time')
# (89, 'By')
# (90, 'its')
# (91, 'end')
# (92, 'the')
# (93, 'series')
# (94, 'was')
# (95, 'among')
# (96, 'the')
# (97, 'mostwatched')
# (98, 'cable')
# (99, 'shows')
# (100, 'on')
# (101, 'American')
# (102, 'television')
# (103, 'with')
# (104, 'audience')
# (105, 'numbers')
# (106, 'doubling')
# (107, 'from')
# (108, 'the')
# (109, 'fourth')
# (110, 'season')
# (111, 'to')
# (112, 'the')
# (113, 'fifth')
# (114, 'A')
# (115, '2015')
# (116, 'survey')
# (117, 'by')
# (118, 'The')
# (119, 'Hollywood')
# (120, 'Reporter')
# (121, 'of')
# (122, '2800')
# (123, 'actors')
# (124, 'producers')
# (125, 'directors')
# (126, 'and')
# (127, 'other')
# (128, 'industry')
# (129, 'people')
# (130, 'named')
# (131, 'Breaking')
# (132, 'Bad')
# (133, 'as')
# (134, 'their')
# (135, '2')
# (136, 'favorite')
# (137, 'show')
# (138, 'In')
# (139, '2016')
# (140, 'Rolling')
# (141, 'Stone')
# (142, 'ranked')
# (143, 'it')
# (144, 'third')
# (145, 'on')
# (146, 'its')
# (147, 'list')
# (148, 'of')
# (149, '100')
# (150, 'Greatest')
# (151, 'TV')
# (152, 'Shows')
# (153, 'of')
# (154, 'All')
# (155, 'Time')
# (156, 'In')
# (157, 'September')
# (158, '2019')
# (159, 'The')
# (160, 'Guardian')
# (161, 'ranked')
# (162, 'the')
# (163, 'show')
# (164, 'fifth')
# (165, 'on')
# (166, 'its')
# (167, 'list')
# (168, 'of')
# (169, 'the')
# (170, '100')
# (171, 'best')
# (172, 'TV')
# (173, 'shows')
# (174, 'of')
# (175, 'the')
# (176, '21st')
# (177, 'century')
# (178, 'describing')
# (179, 'it')
# (180, 'as')
# (181, 'The')
# (182, 'show')
# (183, 'that')
# (184, 'arguably')
# (185, 'killed')
# (186, 'off')
# (187, 'the')
# (188, 'antihero')
# (189, 'drama')
# (190, 'nothing')
# (191, 'since')
# (192, 'has')
# (193, 'been')
# (194, 'able')
# (195, 'to')
# (196, 'top')
# (197, 'the')
# (198, 'depraved')
# (199, 'descent')
# (200, 'made')
# (201, 'by')
# (202, 'Walter')
# (203, 'White')
# (204, 'a')
# (205, 'neverbetter')
# (206, 'Bryan')
# (207, 'Cranston')
# (208, 'from')
# (209, 'milquetoast')
# (210, 'chemistry')
# (211, 'teacher')
# (212, 'to')
# (213, 'meth')
# (214, 'overlord')
# (215, 'and')
# (216, 'few')
# (217, 'have')
# (218, 'dared')
# (219, 'to')
# (220, 'try')
# (221, 'In')
# (222, '2021')
# (223, 'Empire')
# (224, 'ranked')
# (225, 'Breaking')
# (226, 'Bad')
# (227, 'at')
# (228, 'number')
# (229, 'one')
# (230, 'on')
# (231, 'their')
# (232, 'list')
# (233, 'of')
# (234, 'The')
# (235, '100')
# (236, 'Greatest')
# (237, 'TV')
# (238, 'Shows')
# (239, 'of')
# (240, 'All')
# (241, 'Time')
# (242, 'Allen')
# (243, 'St')
# (244, 'John')
# (245, 'of')
# (246, 'Forbes')
# (247, 'called')
# (248, 'it')
# (249, 'The')
# (250, 'best')
# (251, 'TV')
# (252, 'show')
# (253, 'ever')
# (254, 'In')
# (255, '2021')
# (256, 'it')
# (257, 'was')
# (258, 'voted')
# (259, 'the')
# (260, 'thirdbest')
# (261, 'TV')
# (262, 'series')
# (263, 'of')
# (264, 'the')
# (265, '21st')
# (266, 'century')
# (267, 'by')
# (268, 'the')
# (269, 'BBC')
# (270, 'as')
# (271, 'picked')
# (272, 'by')
# (273, '206')
# (274, 'TV')
# (275, 'experts')
# (276, 'from')
# (277, 'around')
# (278, 'the')
# (279, 'worldFor')
# (280, 'the')
# (281, 'first')
# (282, 'season')
# (283, 'the')
# (284, 'series')
# (285, 'saw')
# (286, 'a')
# (287, 'generally')
# (288, 'positive')
# (289, 'reception')
# (290, 'New')
# (291, 'York')
# (292, 'Post')
# (293, 'critic')
# (294, 'Linda')
# (295, 'Stasi')
# (296, 'praised')
# (297, 'the')
# (298, 'series')
# (299, 'particularly')
# (300, 'the')
# (301, 'acting')
# (302, 'of')
# (303, 'Cranston')
# (304, 'and')
# (305, 'Paul')
# (306, 'stating')
# (307, 'Cranston')
# (308, 'and')
# (309, 'Paul')
# (310, 'are')
# (311, 'so')
# (312, 'good')
# (313, 'its')
# (314, 'astounding')
# (315, 'Id')
# (316, 'say')
# (317, 'the')
# (318, 'two')
# (319, 'have')
# (320, 'created')
# (321, 'great')
# (322, 'chemistry')
# (323, 'but')
# (324, 'Im')
# (325, 'ashamed')
# (326, 'to')
# (327, 'say')
# (328, 'such')
# (329, 'a')
# (330, 'cheap')
# (331, 'thing')
# (332, 'Robert')
# (333, 'Bianco')
# (334, 'of')
# (335, 'USA')
# (336, 'Today')
# (337, 'also')
# (338, 'praised')
# (339, 'Cranston')
# (340, 'and')
# (341, 'Paul')
# (342, 'exclaiming')
# (343, 'There')
# (344, 'is')
# (345, 'humor')
# (346, 'in')
# (347, 'the')
# (348, 'show')
# (349, 'mostly')
# (350, 'in')
# (351, 'Walts')
# (352, 'efforts')
# (353, 'to')
# (354, 'impose')
# (355, 'scholarly')
# (356, 'logic')
# (357, 'on')
# (358, 'the')
# (359, 'business')
# (360, 'and')
# (361, 'on')
# (362, 'his')
# (363, 'idiot')
# (364, 'apprentice')
# (365, 'a')
# (366, 'role')
# (367, 'Paul')
# (368, 'plays')
# (369, 'very')
# (370, 'well')
# (371, 'But')
# (372, 'even')
# (373, 'their')
# (374, 'scenes')
# (375, 'lean')
# (376, 'toward')
# (377, 'the')
# (378, 'suspenseful')
# (379, 'as')
# (380, 'the')
# (381, 'duo')
# (382, 'learns')
# (383, 'that')
# (384, 'killing')
# (385, 'someone')
# (386, 'even')
# (387, 'in')
# (388, 'selfdefense')
# (389, 'is')
# (390, 'ugly')
# (391, 'messy')
# (392, 'workThe')
# (393, 'second')
# (394, 'season')
# (395, 'saw')
# (396, 'critical')
# (397, 'acclaim')
# (398, 'Entertainment')
# (399, 'Weekly')
# (400, 'critic')
# (401, 'Ken')
# (402, 'Tucker')
# (403, 'stated')
# (404, 'Bad')
# (405, 'is')
# (406, 'a')
# (407, 'superlatively')
# (408, 'fresh')
# (409, 'metaphor')
# (410, 'for')
# (411, 'a')
# (412, 'middleage')
# (413, 'crisis')
# (414, 'It')
# (415, 'took')
# (416, 'cancer')
# (417, 'and')
# (418, 'lawbreaking')
# (419, 'to')
# (420, 'jolt')
# (421, 'Walt')
# (422, 'out')
# (423, 'of')
# (424, 'his')
# (425, 'suburban')
# (426, 'stupor')
# (427, 'to')
# (428, 'experience')
# (429, 'life')
# (430, 'againto')
# (431, 'take')
# (432, 'chances')
# (433, 'risk')
# (434, 'danger')
# (435, 'do')
# (436, 'things')
# (437, 'he')
# (438, 'didnt')
# (439, 'think')
# (440, 'himself')
# (441, 'capable')
# (442, 'of')
# (443, 'doing')
# (444, 'None')
# (445, 'of')
# (446, 'this')
# (447, 'would')
# (448, 'work')
# (449, 'of')
# (450, 'course')
# (451, 'without')
# (452, 'Emmy')
# (453, 'winner')
# (454, 'Cranstons')
# (455, 'ferocious')
# (456, 'funny')
# (457, 'selflessness')
# (458, 'as')
# (459, 'an')
# (460, 'actor')
# (461, 'For')
# (462, 'all')
# (463, 'its')
# (464, 'bleakness')
# (465, 'and')
# (466, 'darkness')
# (467, 'theres')
# (468, 'a')
# (469, 'glowing')
# (470, 'exhilaration')
# (471, 'about')
# (472, 'this')
# (473, 'series')
# (474, 'Its')
# (475, 'a')
# (476, 'feelgood')
# (477, 'show')
# (478, 'about')
# (479, 'feeling')
# (480, 'really')
# (481, 'bad')
# (482, 'San')
# (483, 'Francisco')
# (484, 'Chronicles')
# (485, 'Tim')
# (486, 'Goodman')
# (487, 'claimed')
# (488, 'The')
# (489, 'first')
# (490, 'three')
# (491, 'episodes')
# (492, 'of')
# (493, 'Season')
# (494, '2')
# (495, 'that')
# (496, 'AMC')
# (497, 'sent')
# (498, 'out')
# (499, 'continue')
# (500, 'that')
# (501, 'level')
# (502, 'of')
# (503, 'achievement')
# (504, 'with')
# (505, 'no')
# (506, 'evident')
# (507, 'missteps')
# (508, 'In')
# (509, 'fact')
# (510, 'it')
# (511, 'looks')
# (512, 'as')
# (513, 'if')
# (514, 'Gilligans')
# (515, 'bold')
# (516, 'vision')
# (517, 'for')
# (518, 'Breaking')
# (519, 'Bad')
# (520, 'now')
# (521, 'duly')
# (522, 'rewarded')
# (523, 'against')
# (524, 'all')
# (525, 'odds')
# (526, 'has')
# (527, 'invigorated')
# (528, 'everyone')
# (529, 'involved')
# (530, 'in')
# (531, 'the')
# (532, 'project')
# (533, 'You')
# (534, 'can')
# (535, 'sense')
# (536, 'its')
# (537, 'maturity')
# (538, 'and')
# (539, 'rising')
# (540, 'ambition')
# (541, 'in')
# (542, 'each')
# (543, 'episode')
# (544, 'Horror')
# (545, 'novelist')
# (546, 'Stephen')
# (547, 'King')
# (548, 'lauded')
# (549, 'the')
# (550, 'series')
# (551, 'comparing')
# (552, 'it')
# (553, 'to')
# (554, 'the')
# (555, 'likes')
# (556, 'of')
# (557, 'Twin')
# (558, 'Peaks')
# (559, 'and')
# (560, 'Blue')
# (561, 'Velvet')
# (562, 'The')
# (563, 'third')
# (564, 'season')
# (565, 'also')
# (566, 'saw')
# (567, 'critical')
# (568, 'acclaim')
# (569, 'Time')
# (570, 'proclaimed')
# (571, 'Its')
# (572, 'a')
# (573, 'drama')
# (574, 'that')
# (575, 'has')
# (576, 'chosen')
# (577, 'the')
# (578, 'slow')
# (579, 'burn')
# (580, 'over')
# (581, 'the')
# (582, 'flashy')
# (583, 'explosion')
# (584, 'and')
# (585, 'its')
# (586, 'all')
# (587, 'the')
# (588, 'hotter')
# (589, 'for')
# (590, 'that')
# (591, 'choice')
# (592, 'Newsday')
# (593, 'stated')
# (594, 'Breaking')
# (595, 'Bad')
# (596, 'was')
# (597, 'still')
# (598, 'TVs')
# (599, 'best')
# (600, 'series')
# (601, 'and')
# (602, 'it')
# (603, 'stayed')
# (604, 'true')
# (605, 'to')
# (606, 'itself')
# (607, 'Tim')
# (608, 'Goodman')
# (609, 'praised')
# (610, 'the')
# (611, 'writing')
# (612, 'acting')
# (613, 'and')
# (614, 'cinematography')
# (615, 'pointing')
# (616, 'out')
# (617, 'the')
# (618, 'visual')
# (619, 'adventurousness')
# (620, 'of')
# (621, 'the')
# (622, 'series')
# (623, 'Goodman')
# (624, 'went')
# (625, 'on')
# (626, 'to')
# (627, 'call')
# (628, 'the')
# (629, 'shows')
# (630, 'visuals')
# (631, 'a')
# (632, 'combination')
# (633, 'of')
# (634, 'staggering')
# (635, 'beauty')
# (636, 'the')
# (637, 'directors')
# (638, 'make')
# (639, 'use')
# (640, 'of')
# (641, 'numerous')
# (642, 'wideangle')
# (643, 'landscape')
# (644, 'portraits')
# (645, 'and')
# (646, 'transfixing')
# (647, 'weirdness')
# (648, 'After')
# (649, 'the')
# (650, 'finale')
# (651, 'aired')
# (652, 'The')
# (653, 'AV')
# (654, 'Club')
# (655, 'said')
# (656, 'that')
# (657, 'season')
# (658, 'three')
# (659, 'was')
# (660, 'one')
# (661, 'of')
# (662, 'televisions')
# (663, 'finest')
# (664, 'dramatic')
# (665, 'accomplishments')
# (666, 'And')
# (667, 'what')
# (668, 'makes')
# (669, 'it')
# (670, 'so')
# (671, 'exciting')
# (672, 'what')
# (673, 'makes')
# (674, 'the')
# (675, 'recognition')
# (676, 'of')
# (677, 'the')
# (678, 'current')
# (679, 'golden')
# (680, 'age')
# (681, 'so')
# (682, 'pressing')
# (683, 'is')
# (684, 'that')
# (685, 'the')
# (686, 'season')
# (687, 'has')
# (688, 'not')
# (689, 'been')
# (690, 'as')
# (691, 'another')
# (692, 'reviewer')
# (693, 'put')
# (694, 'it')
# (695, 'in')
# (696, 'another')
# (697, 'context')
# (698, 'television')
# (699, 'good')
# (700, 'The')
# (701, 'heartinthethroat')
# (702, 'quality')
# (703, 'of')
# (704, 'this')
# (705, 'season')
# (706, 'comes')
# (707, 'as')
# (708, 'much')
# (709, 'from')
# (710, 'the')
# (711, 'writers')
# (712, 'exhilarating')
# (713, 'disregard')
# (714, 'for')
# (715, 'television')
# (716, 'conventions')
# (717, 'as')
# (718, 'from')
# (719, 'the')
# (720, 'events')
# (721, 'portrayedSeason')
# (722, 'four')
# (723, 'won')
# (724, 'nearuniversal')
# (725, 'critical')
# (726, 'acclaim')
# (727, 'The')
# (728, 'Boston')
# (729, 'Globe')
# (730, 'referred')
# (731, 'to')
# (732, 'the')
# (733, 'show')
# (734, 'as')
# (735, 'a')
# (736, 'taut')
# (737, 'exercise')
# (738, 'in')
# (739, 'withheld')
# (740, 'disaster')
# (741, 'and')
# (742, 'declared')
# (743, 'the')
# (744, 'show')
# (745, 'riveting')
# (746, 'The')
# (747, 'Pittsburgh')
# (748, 'PostGazette')
# (749, 'labeled')
# (750, 'the')
# (751, 'series')
# (752, 'smart')
# (753, 'and')
# (754, 'thought')
# (755, 'provoking')
# (756, 'that')
# (757, 'elevates')
# (758, 'the')
# (759, 'artistic')
# (760, 'achievements')
# (761, 'of')
# (762, 'the')
# (763, 'medium')
# (764, 'Season')
# (765, 'four')
# (766, 'was')
# (767, 'listed')
# (768, 'by')
# (769, 'many')
# (770, 'critics')
# (771, 'as')
# (772, 'one')
# (773, 'of')
# (774, 'the')
# (775, 'best')
# (776, 'seasons')
# (777, 'of')
# (778, 'television')
# (779, 'in')
# (780, '2011')
# (781, 'Time')
# (782, 'listed')
# (783, 'Walter')
# (784, 'Whites')
# (785, 'I')
# (786, 'am')
# (787, 'the')
# (788, 'one')
# (789, 'who')
# (790, 'knocks')
# (791, 'line')
# (792, 'as')
# (793, 'one')
# (794, 'of')
# (795, 'the')
# (796, 'best')
# (797, 'television')
# (798, 'lines')
# (799, 'of')
# (800, '2011')
# (801, 'The')
# (802, 'Pittsburgh')
# (803, 'PostGazette')
# (804, 'listed')
# (805, 'it')
# (806, 'as')
# (807, 'the')
# (808, 'best')
# (809, 'series')
# (810, 'of')
# (811, '2011')
# (812, 'while')
# (813, 'noting')
# (814, 'that')
# (815, 'Breaking')
# (816, 'Bad')
# (817, 'is')
# (818, 'that')
# (819, 'rare')
# (820, 'TV')
# (821, 'series')
# (822, 'that')
# (823, 'has')
# (824, 'never')
# (825, 'made')
# (826, 'a')
# (827, 'seriously')
# (828, 'damaging')
# (829, 'storytelling')
# (830, 'misstep')
# (831, 'The')
# (832, 'AV')
# (833, 'Clubs')
# (834, 'review')
# (835, 'of')
# (836, 'the')
# (837, 'finale')
# (838, 'summed')
# (839, 'it')
# (840, 'up')
# (841, 'as')
# (842, 'a')
# (843, 'fantastically')
# (844, 'fitting')
# (845, 'end')
# (846, 'for')
# (847, 'a')
# (848, 'season')
# (849, 'that')
# (850, 'ran')
# (851, 'in')
# (852, 'slow')
# (853, 'motion')
# (854, 'starting')
# (855, 'and')
# (856, 'continuing')
# (857, 'with')
# (858, 'so')
# (859, 'many')
# (860, 'crises')
# (861, 'begging')
# (862, 'for')
# (863, 'resolution')
# (864, 'week')
# (865, 'after')
# (866, 'week')
# (867, 'Now')
# (868, 'the')
# (869, 'decks')
# (870, 'are')
# (871, 'cleared')
# (872, 'but')
# (873, 'that')
# (874, 'doesnt')
# (875, 'mean')
# (876, 'anybody')
# (877, 'is')
# (878, 'home')
# (879, 'free')
# (880, 'Nothings')
# (881, 'ever')
# (882, 'easy')
# (883, 'on')
# (884, 'Breaking')
# (885, 'Bad')
# (886, 'The')
# (887, 'reviewer')
# (888, 'continued')
# (889, 'to')
# (890, 'exalt')
# (891, 'the')
# (892, 'season')
# (893, 'and')
# (894, 'proclaimed')
# (895, 'What')
# (896, 'a')
# (897, 'season')
# (898, 'of')
# (899, 'television')
# (900, 'truly')
# (901, 'something')
# (902, 'none')
# (903, 'of')
# (904, 'us')
# (905, 'could')
# (906, 'ever')
# (907, 'have')
# (908, 'expected')
# (909, 'or')
# (910, 'claimed')
# (911, 'we')
# (912, 'deservedBoth')
# (913, 'halves')
# (914, 'of')
# (915, 'the')
# (916, 'fifth')
# (917, 'season')
# (918, 'received')
# (919, 'overwhelming')
# (920, 'critical')
# (921, 'acclaim')
# (922, 'Following')
# (923, 'the')
# (924, 'end')
# (925, 'of')
# (926, 'the')
# (927, 'series')
# (928, 'critic')
# (929, 'Nick')
# (930, 'Harley')
# (931, 'summarized')
# (932, 'his')
# (933, 'commendation')
# (934, 'of')
# (935, 'the')
# (936, 'show')
# (937, 'Expertly')
# (938, 'written')
# (939, 'virtuosic')
# (940, 'with')
# (941, 'its')
# (942, 'direction')
# (943, 'and')
# (944, 'flawlessly')
# (945, 'performed')
# (946, 'Breaking')
# (947, 'Bad')
# (948, 'is')
# (949, 'everything')
# (950, 'you')
# (951, 'could')
# (952, 'want')
# (953, 'in')
# (954, 'a')
# (955, 'drama')
# (956, 'Critics')
# (957, 'will')
# (958, 'spend')
# (959, 'the')
# (960, 'next')
# (961, 'decade')
# (962, 'dissecting')
# (963, 'and')
# (964, 'arguing')
# (965, 'about')
# (966, 'what')
# (967, 'made')
# (968, 'it')
# (969, 'great')
# (970, 'but')
# (971, 'the')
# (972, 'reasons')
# (973, 'are')
# (974, 'endless')
# (975, 'and')
# (976, 'already')
# (977, 'well')
# (978, 'documented')
# (979, 'During')
# (980, 'the')
# (981, 'final')
# (982, 'season')
# (983, 'the')
# (984, 'show')
# (985, 'also')
# (986, 'received')
# (987, 'praise')
# (988, 'from')
# (989, 'George')
# (990, 'R')
# (991, 'R')
# (992, 'Martin')
# (993, 'author')
# (994, 'of')
# (995, 'the')
# (996, 'A')
# (997, 'Song')
# (998, 'of')
# (999, 'Ice')
# (1000, 'and')
# (1001, 'Fire')
# (1002, 'novels')
# (1003, 'particularly')
# (1004, 'the')
# (1005, 'episode')
# (1006, 'Ozymandias')
# (1007, 'Martin')
# (1008, 'commented')
# (1009, 'that')
# (1010, 'Walter')
# (1011, 'White')
# (1012, 'is')
# (1013, 'a')
# (1014, 'bigger')
# (1015, 'monster')
# (1016, 'than')
# (1017, 'anyone')
# (1018, 'in')
# (1019, 'Westeros')
# (1020, 'In')
# (1021, 'his')
# (1022, 'review')
# (1023, 'of')
# (1024, 'the')
# (1025, 'second')
# (1026, 'half')
# (1027, 'of')
# (1028, 'season')
# (1029, '5')
# (1030, 'Seth')
# (1031, 'Amitin')
# (1032, 'of')
# (1033, 'IGN')
# (1034, 'stated')
# (1035, 'This')
# (1036, 'final')
# (1037, 'batch')
# (1038, 'of')
# (1039, 'Breaking')
# (1040, 'Bad')
# (1041, 'is')
# (1042, 'one')
# (1043, 'of')
# (1044, 'the')
# (1045, 'best')
# (1046, 'run')
# (1047, 'of')
# (1048, 'episodes')
# (1049, 'TV')
# (1050, 'has')
# (1051, 'ever')
# (1052, 'offered')
# (1053, 'and')
# (1054, 'praised')
# (1055, 'Ozymandias')
# (1056, 'in')
# (1057, 'particular')
# (1058, 'referring')
# (1059, 'to')
# (1060, 'it')
# (1061, 'as')
# (1062, 'maybe')
# (1063, 'the')
# (1064, 'best')
# (1065, 'episode')
# (1066, 'of')
# (1067, 'TV')
# (1068, 'hes')
# (1069, 'ever')
# (1070, 'seen')
# (1071, 'Jonah')
# (1072, 'Goldberg')
# (1073, 'of')
# (1074, 'National')
# (1075, 'Review')
# (1076, 'called')
# (1077, 'it')
# (1078, 'the')
# (1079, 'best')
# (1080, 'show')
# (1081, 'currently')
# (1082, 'on')
# (1083, 'television')
# (1084, 'and')
# (1085, 'perhaps')
# (1086, 'even')
# (1087, 'the')
# (1088, 'best')
# (1089, 'ever')
# (1090, 'The')
# (1091, 'veteran')
# (1092, 'actor')
# (1093, 'Sir')
# (1094, 'Anthony')
# (1095, 'Hopkins')
# (1096, 'wrote')
# (1097, 'a')
# (1098, 'letter')
# (1099, 'of')
# (1100, 'praise')
# (1101, 'to')
# (1102, 'Bryan')
# (1103, 'Cranston')
# (1104, 'telling')
# (1105, 'him')
# (1106, 'that')
# (1107, 'his')
# (1108, 'performance')
# (1109, 'as')
# (1110, 'Walter')
# (1111, 'White')
# (1112, 'was')
# (1113, 'the')
# (1114, 'best')
# (1115, 'acting')
# (1116, 'I')
# (1117, 'have')
# (1118, 'seen')
# (1119, 'ever')
# (1120, 'He')
# (1121, 'lauded')
# (1122, 'the')
# (1123, 'rest')
# (1124, 'of')
# (1125, 'the')
# (1126, 'cast')
# (1127, 'and')
# (1128, 'crew')
# (1129, 'as')
# (1130, 'well')
# (1131, 'The')
# (1132, 'letter')
# (1133, 'first')
# (1134, 'appeared')
# (1135, 'on')
# (1136, 'Steven')
# (1137, 'Michael')
# (1138, 'Quezadas')
# (1139, 'who')
# (1140, 'portrayed')
# (1141, 'DEA')
# (1142, 'Agent')
# (1143, 'Steven')
# (1144, 'Gomez')
# (1145, 'Facebook')
# (1146, 'page')
# (1147, 'and')
# (1148, 'in')
# (1149, 'spite')
# (1150, 'of')
# (1151, 'it')
# (1152, 'being')
# (1153, 'taken')
# (1154, 'down')
# (1155, 'the')
# (1156, 'letter')
# (1157, 'soon')
# (1158, 'went')
# (1159, 'viral')
# (1160, 'In')
# (1161, '2013')
# (1162, 'Guinness')
# (1163, 'World')
# (1164, 'Records')
# (1165, 'named')
# (1166, 'Breaking')
# (1167, 'Bad')
# (1168, 'the')
# (1169, 'highestrated')
# (1170, 'TV')
# (1171, 'series')
# (1172, 'of')
# (1173, 'all')
# (1174, 'time')
# (1175, 'citing')
# (1176, 'its')
# (1177, 'season')
# (1178, '5')
# (1179, 'Metacritic')
# (1180, 'score')
# (1181, 'of')
# (1182, '99')
# (1183, 'out')
# (1184, 'of')
# (1185, '100')

# %%
#Importanto a função stopwords
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Verificando quais stop words existem no idioma do texto.
stop_words = stopwords.words('english')
print(stop_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# Criando uma nova lista
# Prenchendo a nova lista, retirando stopwords da lista texto.
texto = [w for w in text_clean if not w.lower() in stop_words]
texto = []

# %%
# Adicionando palavras da list_tokes para na lista texto, não sendo stop words.
for w in List_tokens:
    if w not in stop_words:
        texto.append(w)

# %%
# TRansformando a lista para minusculo.
for i in range(len(texto)):
    texto[i] = texto[i].lower()

print(texto)
# Out:
# ['breaking', 'bad', 'received', 'widespread', 'critical', 'acclaim', 'praised', 'many', 'critics', 'one', 'greatest', 'television', 'shows', 'time', 'on', 'review', 'aggregator', 'website', 'metacritic', 'using', 'scale', '0100', 'first', 'season', 'scored', '73', 'second', '84', 'third', '89', 'fourth', '96', 'fifth', '99', 'the', 'american', 'film', 'institute', 'listed', 'breaking', 'bad', 'one', 'top', 'ten', 'television', 'series', '2008', '2010', '2011', '2012', '2013', 'in', '2013', 'tv', 'guide', 'ranked', 'ninth', 'greatest', 'tv', 'series', 'time', 'by', 'end', 'series', 'among', 'mostwatched', 'cable', 'shows', 'american', 'television', 'audience', 'numbers', 'doubling', 'fourth', 'season', 'fifth', 'a', '2015', 'survey', 'the', 'hollywood', 'reporter', '2800', 'actors', 'producers', 'directors', 'industry', 'people', 'named', 'breaking', 'bad', '2', 'favorite', 'show', 'in', '2016', 'rolling', 'stone', 'ranked', 'third', 'list', '100', 'greatest', 'tv', 'shows', 'all', 'time', 'in', 'september', '2019', 'the', 'guardian', 'ranked', 'show', 'fifth', 'list', '100', 'best', 'tv', 'shows', '21st', 'century', 'describing', 'the', 'show', 'arguably', 'killed', 'antihero', 'drama', 'nothing', 'since', 'able', 'top', 'depraved', 'descent', 'made', 'walter', 'white', 'neverbetter', 'bryan', 'cranston', 'milquetoast', 'chemistry', 'teacher', 'meth', 'overlord', 'dared', 'try', 'in', '2021', 'empire', 'ranked', 'breaking', 'bad', 'number', 'one', 'list', 'the', '100', 'greatest', 'tv', 'shows', 'all', 'time', 'allen', 'st', 'john', 'forbes', 'called', 'the', 'best', 'tv', 'show', 'ever', 'in', '2021', 'voted', 'thirdbest', 'tv', 'series', '21st', 'century', 'bbc', 'picked', '206', 'tv', 'experts', 'around', 'worldfor', 'first', 'season', 'series', 'saw', 'generally', 'positive', 'reception', 'new', 'york', 'post', 'critic', 'linda', 'stasi', 'praised', 'series', 'particularly', 'acting', 'cranston', 'paul', 'stating', 'cranston', 'paul', 'good', 'astounding', 'id', 'say', 'two', 'created', 'great', 'chemistry', 'im', 'ashamed', 'say', 'cheap', 'thing', 'robert', 'bianco', 'usa', 'today', 'also', 'praised', 'cranston', 'paul', 'exclaiming', 'there', 'humor', 'show', 'mostly', 'walts', 'efforts', 'impose', 'scholarly', 'logic', 'business', 'idiot', 'apprentice', 'role', 'paul', 'plays', 'well', 'but', 'even', 'scenes', 'lean', 'toward', 'suspenseful', 'duo', 'learns', 'killing', 'someone', 'even', 'selfdefense', 'ugly', 'messy', 'workthe', 'second', 'season', 'saw', 'critical', 'acclaim', 'entertainment', 'weekly', 'critic', 'ken', 'tucker', 'stated', 'bad', 'superlatively', 'fresh', 'metaphor', 'middleage', 'crisis', 'it', 'took', 'cancer', 'lawbreaking', 'jolt', 'walt', 'suburban', 'stupor', 'experience', 'life', 'againto', 'take', 'chances', 'risk', 'danger', 'things', 'didnt', 'think', '
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt


df = pd.DataFrame(count_word.items(),  columns=['word', 'count']).sort_values('count',ascending=False)
df = df[df['count'] > 1] # somente termos com mais de 1 ocorrências


plt.figure(figsize=(10,24))
sns.set(style="darkgrid")
#mpl.style.use(['seaborn'])
sns.barplot(x=df['count'],y=df.word,color='#69b3a2')
plt.xticks(rotation=90) 
# Add title
plt.title('Words ranking by Critical reception Breaking bad Series');

plt.show()

# %%
#Transformando dicionanrio em STRING
sr = str(count_word)
print(type(sr))
print(f"Converted string: {sr}")
# Out:
# <class 'str'>
# Converted string: Counter({'season': 17, 'the': 17, 'series': 15, 'bad': 13, 'tv': 12, 'breaking': 11, 'show': 11, 'best': 11, 'television': 9, 'one': 8, 'in': 8, 'time': 7, 'ever': 7, 'shows': 6, 'critical': 5, 'acclaim': 5, 'praised': 5, 'cranston': 5, 'greatest': 4, 'review': 4, 'first': 4, 'fifth': 4, 'listed': 4, '2011': 4, 'ranked': 4, '100': 4, 'walter': 4, 'paul': 4, 'received': 3, 'many': 3, 'critics': 3, 'second': 3, 'third': 3, '2013': 3, 'end': 3, 'list': 3, 'drama': 3, 'made': 3, 'white': 3, 'saw': 3, 'critic': 3, 'acting': 3, 'also': 3, 'well': 3, 'even': 3, 'stated': 3, 'goodman': 3, 'episode': 3, 'letter': 3, 'metacritic': 2, 'fourth': 2, '99': 2, 'american': 2, 'top': 2, 'a': 2, 'directors': 2, 'named': 2, '2': 2, 'all': 2, '21st': 2, 'century': 2, 'bryan': 2, 'chemistry': 2, '2021': 2, 'called': 2, 'particularly': 2, 'good': 2, 'say': 2, 'great': 2, 'none': 2, 'actor': 2, 'its': 2, 'tim': 2, 'claimed': 2, 'three': 2, 'episodes': 2, 'lauded': 2, 'proclaimed': 2, 'slow': 2, 'went': 2, 'finale': 2, 'av': 2, 'makes': 2, 'another': 2, 'reviewer': 2, 'four': 2, 'pittsburgh': 2, 'postgazette': 2, 'i': 2, 'week': 2, 'could': 2, 'final': 2, 'praise': 2, 'r': 2, 'martin': 2, 'ozymandias': 2, '5': 2, 'seen': 2, 'steven': 2, 'widespread': 1, 'on': 1, 'aggregator': 1, 'website': 1, 'using': 1, 'scale': 1, '0100': 1, 'scored': 1, '73': 1, '84': 1, '89': 1, '96': 1, 'film': 1, 'institute': 1, 'ten': 1, '2008': 1, '2010': 1, '2012': 1, 'guide': 1, 'ninth': 1, 'by': 1, 'among': 1, 'mostwatched': 1, 'cable': 1, 'audience': 1, 'numbers': 1, 'doubling': 1, '2015': 1, 'survey': 1, 'hollywood': 1, 'reporter': 1, '2800': 1, 'actors': 1, 'producers': 1, 'industry': 1, 'people': 1, 'favorite': 1, '2016': 1, 'rolling': 1, 'stone': 1, 'september': 1, '2019': 1, 'guardian': 1, 'describing': 1, 'arguably': 1, 'killed': 1, 'antihero': 1, 'nothing': 1, 'since': 1, 'able': 1, 'depraved': 1, 'descent': 1, 'neverbetter': 1, 'milquetoast': 1, 'teacher': 1, 'meth': 1, 'overlord': 1, 'dared': 1, 'try': 1, 'empire': 1, 'number': 1, 'allen': 1, 'st': 1, 'john': 1, 'forbes': 1, 'voted': 1, 'thirdbest': 1, 'bbc': 1, 'picked': 1, '206': 1, 'experts': 1, 'around': 1, 'worldfor': 1, 'generally': 1, 'positive': 1, 'reception': 1, 'new': 1, 'york': 1, 'post': 1, 'linda': 1, 'stasi': 1, 'stating': 1, 'astounding': 1, 'id': 1, 'two': 1, 'created': 1, 'im': 1, 'ashamed': 1, 'cheap': 1, 'thing': 1, 'robert': 1, 'bianco': 1, 'usa': 1, 'today': 1, 'exclaiming': 1, 'there': 1, 'humor': 1, 'mostly': 1, 'walts': 1, 'efforts': 1, 'impose': 1, 'scholarly': 1, 'logic': 1, 'business': 1, 'idiot': 1, 'apprentice': 1, 'role': 1, 'plays': 1, 'but': 1, 'scenes': 1, 'lean': 1, 'toward': 1, 'suspenseful': 1, 'duo': 1, 'learns': 1, 'killing': 1, 'someone': 1, 'selfdefense': 1, 'ugly': 1, 'messy': 1, 'workthe': 1, 'entertainment': 1, 'weekly': 1, 'ken': 1, 'tucker': 1, 'superlatively': 1, 'fresh': 1, 'metaphor': 1, 'middleage': 1, 'crisis': 1, 'it': 1, 'took': 1, 'cancer': 1, 'lawbreaking': 1, 'jolt': 1, 'walt': 1, 'suburban': 1, 'stupor': 1, 'experience': 1, 'life': 1, 'againto': 1, 'take': 1, 'chances': 1, 'risk': 1, 'danger': 1, 'things': 1, 'didnt': 1, 'think': 1, 'capable': 1, 'would': 1, 'work': 1, 'course': 1, 'without': 1, 'emmy': 1, 'winner': 1, 'cranstons': 1, 'ferocious': 1, 'funny': 1, 'selflessness': 1, 'for': 1, 'bleakness': 1, 'darkness': 1, 'theres': 1, 'glowing': 1, 'exhilaration': 1, 'feelgood': 1, 'feeling': 1, 'really': 1, 'san': 1, 'francisco': 1, 'chronicles': 1, 'amc': 1, 'sent': 1, 'continue': 1, 'level': 1, 'achievement': 1, 'evident': 1, 'missteps': 1, 'fact': 1, 'looks': 1, 'gilligans': 1, 'bold': 1, 'vision': 1, 'duly': 1, 'rewarded': 1, 'odds': 1, 'invigorated': 1, 'everyone': 1, 'involved': 1, 'project': 1, 'you': 1, 'sense': 1, 'maturity': 1, 'rising': 1, 'ambition': 1, 'horror': 1, 'novelist': 1, 'stephen': 1, 'king': 1, 'comparing': 1, 'likes': 1, 'twin': 1, 'peaks': 1, 'blue': 1, 'velvet': 1, 'chosen': 1, 'burn': 1, 'flashy': 1, 'explosion': ...

# %%
#Criando Wordcloud

from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Create lsita de palabras
texto_cloud_word = count_word 

# Create the wordcloud object
wordcloud = WordCloud(width=600, height=1000, margin=0).generate(sr)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# **Conclusão:**
# Podemos observar lei de Zipf de fato funciona avaliando as frequências de palavras para levar a boas pistas sobre o conteúdo geral do texto. É claro que ela é uma aproximação, pois a linguística é uma ciência humana, sujeita a flutuações. Mas é uma aproximação bastante segura, e uma prova uma prova curiosa de que, diferenças culturais à parte, há laços fortes unindo todas as línguas.
